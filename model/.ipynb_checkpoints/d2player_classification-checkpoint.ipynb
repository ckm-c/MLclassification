# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./dataset/d2arteezy/2ez4rtz - Arteezy 11.000 MMR in Dota 2 ....jpg')

# %%
if img is not None:
    plt.imshow(img)

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (720, 1280)

# %%
gray
# Out:
# array([[ 9,  9,  9, ...,  5,  6,  7],
#        [ 9,  9,  9, ...,  5,  7,  9],
#        [ 9,  9,  9, ...,  5,  8, 11],
#        ...,
#        [25, 25, 26, ..., 26, 26, 28],
#        [25, 25, 26, ..., 32, 28, 21],
#        [25, 25, 25, ..., 30, 27, 25]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray)

# %%
(x,y,w,h)=faces[0]
x,y,w,h
# Out:
# (138, 188, 220, 220)

# %%
face_img=cv2.rectangle(img,(x,y,),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
def get_cropped_image_if_2_eyes(image_path):
    test=[]
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
    faces=face_cascade.detectMultiScale(gray)

    for(x,y,w,h) in faces:
        roi_gray = gray[y:y+h,x:x+w]
        roi_color = img[y:y+h,x:x+w]
        eyes=eye_cascade.detectMultiScale(roi_gray)
        if len(eyes)>=2:
                 test.append(roi_color)
    return test

# %%
cropped_image = get_cropped_image_if_2_eyes('./dataset/d2arteezy/2ez4rtz - Arteezy 11.000 MMR in Dota 2 ....jpg')
for i in range(len(cropped_image)):
    plt.imshow(cropped_image[i])

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs=[]
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
import shutil
if os.path.exists(path_to_cr_data):
    shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
player_file_name = {}

for img_dir in img_dirs:
    count = 1
    player_name = img_dir.split('/')[-1]
    print(player_name)
    player_file_name[player_name]=[]

    
    for entry in os.scandir(img_dir):
        print(entry.path)
        img =cv2.imread(entry.path)
        if img is not None:
            roi_color = get_cropped_image_if_2_eyes(entry.path)
        
        if roi_color is not None:
            cropped_folder = path_to_cr_data+player_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            for i in range(len(roi_color)):    
                cropped_file_name = player_name +str(count)+".png"
                cropped_file_path=cropped_folder + "/" + cropped_file_name
                cv2.imwrite(cropped_file_path,roi_color[i])
                player_file_name[player_name].append(cropped_file_path)
                count+=1
# Out:
# d2arteezy
# ./dataset/d2arteezy\20-20_ EG.Arteezy Answers.jpg
# Generating cropped images in folder:  ./dataset/cropped/d2arteezy
# ./dataset/d2arteezy\2ez4rtz - Arteezy 11.000 MMR in Dota 2 ....jpg
# ./dataset/d2arteezy\A conversation with an Evil Genius....jpg
# ./dataset/d2arteezy\Arteezy (Esports Player) Wiki_ Bio....jpg
# ./dataset/d2arteezy\Arteezy - Artour Babaev - DOTABUFF....jpg
# ./dataset/d2arteezy\Arteezy - Dota 2 Wiki.jpg
# ./dataset/d2arteezy\ARTEEZY - Info_ Stats and Clips....jpg
# ./dataset/d2arteezy\Arteezy - Liquipedia Dota 2 Wiki (1).jpg
# ./dataset/d2arteezy\Arteezy - Liquipedia Dota 2 Wiki (2).jpg
# ./dataset/d2arteezy\Arteezy - Liquipedia Dota 2 Wiki.jpg
# ./dataset/d2arteezy\Arteezy - Luna Highlights _ Dota 2 Pro....jpg
# ./dataset/d2arteezy\Arteezy - Outworld Destroyer Highlights....jpg
# ./dataset/d2arteezy\Arteezy - Slardar Safelane _ Typical....jpg
# ./dataset/d2arteezy\Arteezy - Twitch Streamer Profile & Bio....jpg
# ./dataset/d2arteezy\Arteezy - Twitch.jpg
# ./dataset/d2arteezy\Arteezy - Wikipedia.jpg
# ./dataset/d2arteezy\Arteezy - YouTube.jpg
# ./dataset/d2arteezy\ARTEEZY 1V5 RAMPAGE in TI9_ DO YOU WANT....jpg
# ./dataset/d2arteezy\Arteezy Bio_ Twitter_ Age_ Family....jpg
# ./dataset/d2arteezy\Arteezy has re-joined Evil Geniuses.jpg
# ./dataset/d2arteezy\Arteezy hits 9k_ What next for Dota 2....jpg
# ./dataset/d2arteezy\Arteezy in competetive Dota 2....jpg
# ./dataset/d2arteezy\Arteezy Menjadi Pemain Evil Geniuses....jpg
# ./dataset/d2arteezy\Arteezy Net worth_ Age_ Girlfriend....jpg
# ./dataset/d2arteezy\Arteezy new meme _ r_DotA2.jpg
# ./dataset/d2arteezy\Arteezy next team to join if Secret....jpg
# ./dataset/d2arteezy\Arteezy Out of EG_ - HYPRGAME.jpg
# ./dataset/d2arteezy\Arteezy Practicing Tiny CARRY For TI10....jpg
# ./dataset/d2arteezy\arteezy real name Archives _ Latest Celeb.jpg
# ./dataset/d2arteezy\Arteezy Reveals Why He Stopped Playing....jpg
# ./dataset/d2arteezy\Arteezy single-handedly carries Evil....jpg
# ./dataset/d2arteezy\Arteezy Spectre Aegis Steal on Livestream.jpg
# ./dataset/d2arteezy\Arteezy Talks About CCNC_ Abed and TI9....jpg
# ./dataset/d2arteezy\Arteezy Talks About What He Would Say....jpg
# ./dataset/d2arteezy\Arteezy Talks About Why He Looks Up To... (1).jpg
# ./dataset/d2arteezy\Arteezy Talks About Why He Looks Up To....jpg
# ./dataset/d2arteezy\Arteezy to stand in for Digital Chaos....jpg
# ./dataset/d2arteezy\Arteezy Wants Nerf to Monkey King....jpg
# ./dataset/d2arteezy\Arteezy – Dota_s favourite bad boy....jpg
# ./dataset/d2arteezy\Arteezy.jpg
# ./dataset/d2arteezy\Arteezy_ EE and Fear are playing on the....jpg
# ./dataset/d2arteezy\Arteezy_ _We probably would_ve won TI5....jpg
# ./dataset/d2arteezy\Arteezy_s net worth in 2020 (1).jpg
# ./dataset/d2arteezy\Arteezy_s net worth in 2020.jpg
# ./dataset/d2arteezy\Arteezy´s TI curse is real _ r_DotA2.jpg
# ./dataset/d2arteezy\Artour Babaev (_Arteezy) _ Twitter (1).jpg
# ./dataset/d2arteezy\Artour Babaev (_Arteezy) _ Twitter (2).jpg
# ./dataset/d2arteezy\Artour Babaev (_Arteezy) _ Twitter (3).jpg
# ./dataset/d2arteezy\Artour Babaev (_Arteezy) _ Twitter (4).jpg
# ./dataset/d2arteezy\Artour Babaev (_Arteezy) _ Twitter.jpg
# ./dataset/d2arteezy\Artour Babaev Arteezy Height Weight Net....jpg
# ./dataset/d2arteezy\Artour Babaev on Twitter_ _Happy bday....jpg
# ./dataset/d2arteezy\Artour Babaev _Arteezy_ - Frankfurt....jpg
# ./dataset/d2arteezy\Artour Babaev _Arteezy_ - SteelSeries....jpg
# ./dataset/d2arteezy\Artour _Arteezy_ Babaev during Dota 2....jpg
# ./dataset/d2arteezy\Artour _Arteezy_ Babaev of Evil....jpg
# ./dataset/d2arteezy\BEST 200 IQ Plays & Outplays of Arteezy....jpg
# ./dataset/d2arteezy\Best of Arteezy 2017 _1 - YouTube.jpg
# ./dataset/d2arteezy\CHIEF_ arteezy_ artour_ babaev....jpg
# ./dataset/d2arteezy\cool pic of Arteezy on steelseries page....jpg
# ./dataset/d2arteezy\Dendi vs Arteezy 1v1 Solo The....jpg
# ./dataset/d2arteezy\Dota 2 - Arteezy The Movie - YouTube.jpg
# ./dataset/d2arteezy\Dota 2 - Arteezy_ The Rage of RTZ - Y.jpg
# ./dataset/d2arteezy\Dota 2 Arteezy Positive Mental Attitude....jpg
# ./dataset/d2arteezy\Dota 2 courier vision for flash farming... (1).jpg
# ./dataset/d2arteezy\Dota 2 courier vision for flash farming....jpg
# ./dataset/d2arteezy\Dota 2 esports spectacle... (1).jpg
# ./dataset/d2arteezy\Dota 2 esports spectacle....jpg
# ./dataset/d2arteezy\Dota 2 Feature_ EG.Arteezy_ We knew we ....jpg
# ./dataset/d2arteezy\Dota 2 Feature_ EG.Arteezy_ _As always ....jpg
# ./dataset/d2arteezy\Dota 2 Gameplay - Your Source for the... (1).jpg
# ./dataset/d2arteezy\Dota 2 Gameplay - Your Source for the....jpg
# ./dataset/d2arteezy\Dota 2 News_ Arteezy gets a one match....jpg
# ./dataset/d2arteezy\Dota 2 News_ Evil Geniuses remain....jpg
# ./dataset/d2arteezy\Dota 2 News_ Rosters leaked_ Arteezy....jpg
# ./dataset/d2arteezy\Dota 2 Nickname Change – Game....jpg
# ./dataset/d2arteezy\Dota 2 Player Profile - Arteezy - EG....jpg
# ./dataset/d2arteezy\Dota 2 Pro MMR Gameplay _29....jpg
# ./dataset/d2arteezy\Dota 2 streams....jpg
# ./dataset/d2arteezy\DOTA 2 Videos __ Watch DOTA 2 videos....jpg
# ./dataset/d2arteezy\Dota 2.jpg
# ./dataset/d2arteezy\Dota 2_ Arteezy demolishes Vici Gaming....jpg
# ./dataset/d2arteezy\Dota 2_ Arteezy music_ videos_ stats....jpg
# ./dataset/d2arteezy\Dota 2_ Arteezy_ after playing Abaddon....jpg
# ./dataset/d2arteezy\Dota 2_ Arteezy_ _Espero poder seguir....jpg
# ./dataset/d2arteezy\Dota 2_ Player Arteezy on the Hunt for....jpg
# ./dataset/d2arteezy\Dota2_ EG team also joined the team... (1).jpg
# ./dataset/d2arteezy\Dota2_ EG team also joined the team... (2).jpg
# ./dataset/d2arteezy\Dota2_ EG team also joined the team....jpg
# ./dataset/d2arteezy\Dove (_Doveveve) _ Twitter.jpg
# ./dataset/d2arteezy\EG.ARTEEZY ANTI-MAGE WITH ETHEREAL ....jpg
# ./dataset/d2arteezy\EG.Arteezy _ 20 Questions _ r_DotA2.jpg
# ./dataset/d2arteezy\eSports Players _ Artour _Arteezy_ Babaev.jpg
# ./dataset/d2arteezy\Evil Geniuses - Liquipedia Dota 2 Wiki (1).jpg
# ./dataset/d2arteezy\Evil Geniuses - Liquipedia Dota 2 Wiki.jpg
# ./dataset/d2arteezy\Evil Geniuses Arteezy Apparently A Lisa....jpg
# ./dataset/d2arteezy\Evil Geniuses Arteezy _ Photo by....jpg
# ./dataset/d2arteezy\Evil Geniuses brings on Arteezy and....jpg
# ./dataset/d2arteezy\Evil Geniuses carry player Arteezy....jpg
# ./dataset/d2arteezy\Evil Geniuses on Twitter_ _._Arteezy ....jpg
# ./dataset/d2arteezy\Evil Geniuses_ Arteezy goes live on....jpg
# ./dataset/d2arteezy\Evil Geniuses_ Arteezy outed as huge....jpg
# ./dataset/d2arteezy\Explore the Best Arteezy Art _ DeviantArt.jpg
# ./dataset/d2arteezy\favorite hero....jpg
# ./dataset/d2arteezy\File_EG.Cr1t and EG.Arteezy ....jpg
# ./dataset/d2arteezy\funny Arteezy pictures on iFunny (1).jpg
# ./dataset/d2arteezy\funny Arteezy pictures on iFunny.jpg
# ./dataset/d2arteezy\I Painted Arteezy _ r_DotA2.jpg
# ./dataset/d2arteezy\INTERNATIONAL 2021 DOTA 2....jpg
# ./dataset/d2arteezy\It is destiny of Aui_2000 and Arteezy....jpg
# ./dataset/d2arteezy\Latest Arteezy News _ GAMERS DECIDE.jpg
# ./dataset/d2arteezy\latest players to reach 11_000 MMR....jpg
# ./dataset/d2arteezy\LGD.Arteezy _ - Imgur.jpg
# ./dataset/d2arteezy\Manila Mingle....jpg
# ./dataset/d2arteezy\Mason_ Arteezy Made a Voice Call to....jpg
# ./dataset/d2arteezy\Meet Your Meme-ers_ Arteezy _ r_DotA2.jpg
# ./dataset/d2arteezy\Milos Nedeljkovic on Twitter_ __ti4....jpg
# ./dataset/d2arteezy\No SumaiL was not Throwing Shade at Arteezy.jpg
# ./dataset/d2arteezy\pink pom poms headband... (1).jpg
# ./dataset/d2arteezy\pink pom poms headband....jpg
# ./dataset/d2arteezy\Play Dota 2....jpg
# ./dataset/d2arteezy\played Dota 2 heroes....jpg
# ./dataset/d2arteezy\players to join 11K MMR Club....jpg
# ./dataset/d2arteezy\Pro Players Gameplay _ Spotnet Dota 2....jpg
# ./dataset/d2arteezy\pubstars the future of competitive Dota....jpg
# ./dataset/d2arteezy\RTZ _ Dota 2 Pro MMR Gameplay....jpg
# ./dataset/d2arteezy\r_DotA2.jpg
# ./dataset/d2arteezy\Steam Community __ __ Arteezy.jpg
# ./dataset/d2arteezy\Story of Arteezy_ The _A-God_ (Dota 2....jpg
# ./dataset/d2arteezy\Stream Arteezy Rap by The Horse and The....jpg
# ./dataset/d2arteezy\SUMAIL vs ARTEEZY - 1v1 MID SOLO....jpg
# ./dataset/d2arteezy\Team Secret Celebrates DOTA 2 Win By....jpg
# ./dataset/d2arteezy\Teams_ Dota 2 - Evil Geniuses.jpg
# ./dataset/d2arteezy\The Arteezy Stream_ Does Twitch Chat....jpg
# ./dataset/d2arteezy\The story of Arteezy_ The Dota 2... (1).jpg
# ./dataset/d2arteezy\The story of Arteezy_ The Dota 2... (2).jpg
# ./dataset/d2arteezy\The story of Arteezy_ The Dota 2... (3).jpg
# ./dataset/d2puppey\20-20_ Na`Vi.Puppey.jpg
# ./dataset/d2puppey\2010 Clement _Puppey_ Ivanov_ retweet....jpg
# ./dataset/d2puppey\Attitude Towards Losing.jpg
# ./dataset/d2puppey\betway DOTA 2 on Twitter_ _The....jpg
# ./dataset/d2puppey\Clement Ivanov (_CLEMENTINATOR) _ Twitter (1).jpg
# ./dataset/d2puppey\Clement Ivanov (_CLEMENTINATOR) _ Twitter.jpg
# ./dataset/d2puppey\Clement Ivanov ᐉ Dota 2 ᐊ Puppey Player....jpg
# ./dataset/d2puppey\Clement Puppey Ivanov - TWIFT.jpg
# ./dataset/d2puppey\Clement Puppey Ivanov during Dota 2....jpg
# ./dataset/d2puppey\Clement _Puppey_ Ivanov departs Natus....jpg
# ./dataset/d2puppey\Clement _Puppey_ Ivanov Team Secret....jpg
# ./dataset/d2puppey\deep look after game 2 vs Mineski....jpg
# ./dataset/d2puppey\Dendi vs Na_vi is the highlight of the day.jpg
# ./dataset/d2puppey\Dendi _ Puppey vs NaVi Dota 2....jpg
# ./dataset/d2puppey\Dota 2 Animajor_ DPC Season Wrap....jpg
# ./dataset/d2puppey\Dota 2 Feature_ Puppey at TI10_ _It is....jpg
# ./dataset/d2puppey\Dota 2 Feature_ Puppey Power_ TI_s ONLY....jpg
# ./dataset/d2puppey\DOTA 2 on Twitter_ _Captains Puppey and....jpg
# ./dataset/d2puppey\Dota 2 Singapore Tournament By ONE....jpg
# ./dataset/d2puppey\Dota 2 Team Secret _ iTech Post.jpg
# ./dataset/d2puppey\Dota 2_ Clement _Puppey_ Ivanov TEDx....jpg
# ./dataset/d2puppey\Dota 2_ Puppey and Kuroky -- The... (1).jpg
# ./dataset/d2puppey\Dota 2_ Puppey and Kuroky -- The....jpg
# ./dataset/d2puppey\Dota 2_ Team Secret To Take Break Until....jpg
# ./dataset/d2puppey\Dota 2_ TI10 Team Secret Update_ Puppey....jpg
# ./dataset/d2puppey\DotA News_ Puppey_s state of Nirvana....jpg
# ./dataset/d2puppey\DOTA2 TI3 - Na_vi.Puppey hugs Fan like ....jpg
# ./dataset/d2puppey\Dota2-TI10_ Counting the few remaining....jpg
# ./dataset/d2puppey\Download puppey images for free (1).jpg
# ./dataset/d2puppey\Download puppey images for free.jpg
# ./dataset/d2puppey\Effects of Age on DOTA 2 Performance....jpg
# ./dataset/d2puppey\ESL Dota2 on Twitter_ _4 of the best....jpg
# ./dataset/d2puppey\ESL One Birmingham 2019....jpg
# ./dataset/d2puppey\Esport Legends - Puppey - DOTA 2....jpg
# ./dataset/d2puppey\every TI placing at The International....jpg
# ./dataset/d2puppey\FACEIT Pro League to Dota 2....jpg
# ./dataset/d2puppey\FACEIT Pro League to Dota 2....webp
# ./dataset/d2puppey\FACEIT Pro Leagues for Dota 2 players....jpg
# ./dataset/d2puppey\FACEIT Pro Leagues to Dota 2 » TalkEsport.jpg
# ./dataset/d2puppey\Finally_ Puppey opened his voice about....jpg
# ./dataset/d2puppey\Helena Kristiansson _ ESL _ Flickr.jpg
# ./dataset/d2puppey\IGN SEA - ROG Masters 2016_ Puppey....jpg
# ./dataset/d2puppey\KuroKy and Puppey are the only All-Time....jpg
# ./dataset/d2puppey\KuroKy and Puppey....jpg
# ./dataset/d2puppey\Legendary Captains in the Dota 2 scene....jpg
# ./dataset/d2puppey\like Kuroky looks at Puppey _ r_DotA2.jpg
# ./dataset/d2puppey\like Matu looks at Puppey....jpg
# ./dataset/d2puppey\lll▷ The Best Dota 2 Players of All....jpg
# ./dataset/d2puppey\Matu looks at Puppey....jpg
# ./dataset/d2puppey\MidOne watch out puppey wants to have a....jpg
# ./dataset/d2puppey\midormeepo on Twitter_ __teamsecret the....jpg
# ./dataset/d2puppey\Most effective Dota 2 rosters.jpg
# ./dataset/d2puppey\Na`Vi.Puppey - The Tribute Movie - YouTube.jpg
# ./dataset/d2puppey\New DPC system _very unforgiving__ says....jpg
# ./dataset/d2puppey\Player Spotlight_ Puppey - In Search of... (1).jpg
# ./dataset/d2puppey\Player Spotlight_ Puppey - In Search of... (2).jpg
# ./dataset/d2puppey\Player Spotlight_ Puppey - In Search of....jpg
# ./dataset/d2puppey\professional players – DOTA Nooblets.jpg
# ./dataset/d2puppey\Puppey - Alchetron_ The Free Social....jpg
# ./dataset/d2puppey\Puppey - Dota 2 Wiki (1).jpg
# ./dataset/d2puppey\Puppey - Dota 2 Wiki.jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki (1).jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki (2).jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki (3).jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki (4).jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki (5).jpg
# ./dataset/d2puppey\Puppey - Liquipedia Dota 2 Wiki.jpg
# ./dataset/d2puppey\Puppey - Wikipedia.jpg
# ./dataset/d2puppey\Puppey after winning a hard series....jpg
# ./dataset/d2puppey\Puppey and Dendi Duo... (1).jpg
# ./dataset/d2puppey\Puppey and Dendi Duo....jpg
# ./dataset/d2puppey\Puppey and Kuroky are now officially....jpg
# ./dataset/d2puppey\Puppey and KuroKy Interview with Kaci....jpg
# ./dataset/d2puppey\Puppey answers fan questions « News....jpg
# ./dataset/d2puppey\Puppey Archives – EsportsJunkie.com (1).jpg
# ./dataset/d2puppey\Puppey Archives – EsportsJunkie.com.jpg
# ./dataset/d2puppey\Puppey claims the Dota 2 crown.jpg
# ./dataset/d2puppey\Puppey Clement Ivanov_ Best Dota 2....jpg
# ./dataset/d2puppey\Puppey Dota 2 Png....jpg
# ./dataset/d2puppey\Puppey Dota 2 Profile_ Wiki_ Bio_ Girl....jpg
# ./dataset/d2puppey\Puppey DotA 2_ Bio_ Age_ Height_ Wife....jpg
# ./dataset/d2puppey\Puppey from Team Secret answers your....jpg
# ./dataset/d2puppey\Puppey has Team Secret looking like the....jpg
# ./dataset/d2puppey\Puppey Intimidates _ Dota 2 The....jpg
# ./dataset/d2puppey\Puppey looks to Dendi. _ r_DotA2.jpg
# ./dataset/d2puppey\Puppey N0tail H4nni Most Epic Hype Cast....jpg
# ./dataset/d2puppey\Puppey on DPC_ “I would like to revert....jpg
# ./dataset/d2puppey\Puppey power_ Breaking down Secret_s....jpg
# ./dataset/d2puppey\Puppey reaches for the crown... again.jpg
# ./dataset/d2puppey\Puppey reveals what_s in his TUMI bag....jpg
# ./dataset/d2puppey\Puppey says Team Secret will save....jpg
# ./dataset/d2puppey\Puppey Talks About Team Secret_s....jpg
# ./dataset/d2puppey\Puppey Team Secret DOTA 2 - Coub - The_yythk....jpg
# ./dataset/d2puppey\Puppey vs. EternalEnvy_ Round ....jpg
# ./dataset/d2puppey\puppey _ Dota 2 The International _ Flickr.jpg
# ./dataset/d2puppey\Puppey _ Star Series DOTA 2....jpg
# ./dataset/d2puppey\Puppey « Players « joinDOTA.com.jpg
# ./dataset/d2puppey\Puppey_ 10 Most Interesting Facts You... (1).jpg
# ./dataset/d2puppey\Puppey_ 10 Most Interesting Facts You....jpg
# ./dataset/d2puppey\Puppey_ W33_ Pieliedie_ eternal envy....jpg
# ./dataset/d2puppey\Reddit Dota 2 on Twitter_ __I_m so....jpg
# ./dataset/d2puppey\Reflective Puppey _ Dota 2 The....jpg
# ./dataset/d2puppey\Secret Captain Puppey advised OG....jpg
# ./dataset/d2puppey\Secret Puppey Techies dota 2 ranked....jpg
# ./dataset/d2puppey\Secret.Puppey Post-Match Interview ....jpg
# ./dataset/d2puppey\Secret_ Puppey... (1).jpg
# ./dataset/d2puppey\Secret_ Puppey....jpg
# ./dataset/d2puppey\Team Secret - Liquipedia Dota 2 Wiki.jpg
# ./dataset/d2puppey\Team Secret Captain Puppey reacts....jpg
# ./dataset/d2puppey\Team Secret Drama - Esports Edition.jpg
# ./dataset/d2puppey\Team Secret forges on to grand finals....jpg
# ./dataset/d2puppey\Team Secret new roster to include MP....jpg
# ./dataset/d2puppey\Team Secret Puppey answers your burning....jpg
# ./dataset/d2puppey\Team Secret Puppey Next Time Second....jpg
# ./dataset/d2puppey\Team Secret Puppey_ _Next time second....jpg
# ./dataset/d2puppey\Team Secret With Puppey _ Dota 2....jpg
# ./dataset/d2puppey\Team Secret_s Puppey to OG_ _Stay down....jpg
# ./dataset/d2puppey\Team Stories - Na`Vi - Puppey - The....jpg
# ./dataset/d2puppey\The best Dota 2 players of 2021....jpg
# ./dataset/d2puppey\The Best Dota 2 Teams of 2020 - Xfire.jpg
# ./dataset/d2puppey\The difficulty factor is 9.9_Puppey ... (1).jpg
# ./dataset/d2puppey\The difficulty factor is 9.9_Puppey ....jpg
# ./dataset/d2puppey\The Story of Dota 2 Team Secret – Part_yythk... (1).jpg
# ./dataset/d2puppey\The Story of Dota 2 Team Secret – Part_yythk....jpg
# ./dataset/d2puppey\This is why Puppey is the only player....jpg
# ./dataset/d2puppey\TI4 Interview_ Puppey and EternaLEnVy....jpg
# ./dataset/d2puppey\TIL Puppey had long luscious hair....jpg
# ./dataset/d2puppey\Top 10 Greatest DotA 2 Players.jpg
# ./dataset/d2puppey\Welcome To Dota 2 World __ July 2013.jpg
# ./dataset/d2puppey\WePlay_ Dota 2 Tug of War_ Mad Moon....jpg
# ./dataset/d2puppey\WEU DPC game against Team Secret.jpg
# ./dataset/d2puppey\When Valve is in on the Puppey memes....jpg
# ./dataset/d2puppey\Who is Dota 2_s greatest player of all....jpg
# ./dataset/d2puppey\World Showdown Of Esports - DOTABUFF....jpg
# ./dataset/d2puppey\Young Puppey _ r_DotA2.jpg
# ./dataset/d2puppey\慧眼识英雄！组建Secret的刀圈伯乐Puppey....jpg
# d2zai
# ./dataset/d2zai\2021-03-01】 zai 直播录像_Dota2_哔哩哔哩....jpg
# Generating cropped images in folder:  ./dataset/cropped/d2zai
# ./dataset/d2zai\Bucharest Major - Interview with Zai....jpg
# ./dataset/d2zai\Career interview with Ludwig _Zai... (1).jpg
# ./dataset/d2zai\Career interview with Ludwig _Zai....jpg
# ./dataset/d2zai\circular wire frame glasses Zai....jpg
# ./dataset/d2zai\Dota 2 - Zai Signs for Team Liquid....jpg
# ./dataset/d2zai\DOTA 2 on Twitter_ _Too early for Zai....jpg
# ./dataset/d2zai\Dota 2 Pro Makes Clutch Play From....jpg
# ./dataset/d2zai\Dota 2 Roster News_ Zai Leaves Team....jpg
# ./dataset/d2zai\Dota 2 – Esports....jpg
# ./dataset/d2zai\DOTA 2] Liquid.zai the DOOM [OFFLANE ....jpg
# ./dataset/d2zai\DOTA 2] Liquid.zai the WARLOCK [OFFLANE ....jpg
# ./dataset/d2zai\Dota 2_ DotA_ MOBA _ r_DotA2.jpg
# ./dataset/d2zai\Dota 2_ Zai khẳng định MATUMBAMAN là....jpg
# ./dataset/d2zai\Dota 2_ zai parts ways with Team Secret....jpg
# ./dataset/d2zai\Dota 2_ Zai se _sacrifica_ por su....jpg
# ./dataset/d2zai\DOTA2_ Secret officially announced a....jpg
# ./dataset/d2zai\ESL Dota2 on Twitter_ __Nisha kinda....jpg
# ./dataset/d2zai\ex-TeamSecret Zai now in Team Liquid....jpg
# ./dataset/d2zai\Goodbye Secret.Zai — hello Liquid.Zai ....jpg
# ./dataset/d2zai\I got Zai to smile (almost) _ Dota 2....jpg
# ./dataset/d2zai\I just found this picture of zai from....jpg
# ./dataset/d2zai\Identify Zai in the pic _ r_DotA2.jpg
# ./dataset/d2zai\Interview with EG.Zai and EG.Arteezy ....jpg
# ./dataset/d2zai\Kiev Major_ EG ground Thunderbirds....jpg
# ./dataset/d2zai\Liquid官方宣布zai加入DOTA2队伍.jpg
# ./dataset/d2zai\Ludwig _zai_ Wåhlberg Team Liquid Dota....jpg
# ./dataset/d2zai\Ludwig «Zai» Wahlberg Dota 2_ player....jpg
# ./dataset/d2zai\Pro Players Gameplay _ Spotnet Dota....jpg
# ./dataset/d2zai\Qojqva Switches to Full-Time Streaming....jpg
# ./dataset/d2zai\Reddit Dota 2 on Twitter_ _What if some....jpg
# ./dataset/d2zai\RIP ZAI the grill _ Dota 2_ DotA_ MOBA_yythk....jpg
# ./dataset/d2zai\Sand King performance LUL _ r_DotA2.jpg
# ./dataset/d2zai\School_s Out_ Zai is Back.jpg
# ./dataset/d2zai\Zai Leaves Team Secret and Joins Team....jpg
# ./dataset/d2zai\Zai leaves Team Secret to join Team... (1).jpg
# ./dataset/d2zai\Zai leaves Team Secret to join Team....jpg
# ./dataset/d2zai\Zai Leaves Team Secret_ Roster Shuffle....jpg
# ./dataset/d2zai\Zai looks handsome with the new haircut....jpg
# ./dataset/d2zai\Zai n the bois _ r_DotA2.jpg
# ./dataset/d2zai\Zai NEW Player of Team Liquid __ - YouTube.jpg
# ./dataset/d2zai\Zai return to Evil Geniuses_ Aui....jpg
# ./dataset/d2zai\Zai returns and joins forces with Kaipi....jpg
# ./dataset/d2zai\Zai returns to competitive Dota 2 after....jpg
# ./dataset/d2zai\Zai returns to Dota 2 to join some....jpg
# ./dataset/d2zai\Zai Returns to Team Secret_ Nisha....jpg
# ./dataset/d2zai\Zai reveals why MidOne left Team Secret.jpg
# ./dataset/d2zai\Zai stream with puppey__ _ r_DotA2.jpg
# ./dataset/d2zai\zai takes home your Chongqing MVP award_.jpg
# ./dataset/d2zai\Zai talks Liquid_ Secret_ the DPC_ the....jpg
# ./dataset/d2zai\Zai Team Secret Dota 2....jpg
# ./dataset/d2zai\Zai tillbaka i Evil Geniuses_ Flyttar....jpg
# ./dataset/d2zai\Zai watching UCL final at the OpTic....jpg
# ./dataset/d2zai\zai « Players « joinDOTA.com.jpg
# ./dataset/d2zai\zai « Players « joinDOTA.com.png
# ./dataset/d2zai\zai — Dota 2 Вики.jpg
# ./dataset/d2zai\zai.jpg
# ./dataset/d2zai\zai.png _ r_DotA2.jpg
# ./dataset/d2zai\Zai_ I_m not sure I wanna make a career_yyth....jpg
# ./dataset/d2zai\zai_ _We come here and want to win the_yythk....jpg
# ./dataset/d2zai\Zai_s TI8 Player Card Leaked - Imgur.jpg
# ./dataset/d2zai\ZAI妹_ 搜索结果_哔哩哔哩_Bilibili.jpg
# ./dataset/d2zai\Профиль игрока zai по Dota 2_ новости....jpg

# %%
player_file_name = {}
for img_dir in cropped_image_dirs:
    player_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    player_file_name[player_name] = file_list
player_file_name
# Out:
# {'d2arteezy': ['./dataset/cropped/d2arteezy\\d2arteezy1.png',
#   './dataset/cropped/d2arteezy\\d2arteezy10.png',
#   './dataset/cropped/d2arteezy\\d2arteezy100.png',
#   './dataset/cropped/d2arteezy\\d2arteezy101.png',
#   './dataset/cropped/d2arteezy\\d2arteezy102.png',
#   './dataset/cropped/d2arteezy\\d2arteezy103.png',
#   './dataset/cropped/d2arteezy\\d2arteezy104.png',
#   './dataset/cropped/d2arteezy\\d2arteezy105.png',
#   './dataset/cropped/d2arteezy\\d2arteezy108.png',
#   './dataset/cropped/d2arteezy\\d2arteezy109.png',
#   './dataset/cropped/d2arteezy\\d2arteezy11.png',
#   './dataset/cropped/d2arteezy\\d2arteezy111.png',
#   './dataset/cropped/d2arteezy\\d2arteezy112.png',
#   './dataset/cropped/d2arteezy\\d2arteezy113.png',
#   './dataset/cropped/d2arteezy\\d2arteezy114.png',
#   './dataset/cropped/d2arteezy\\d2arteezy116.png',
#   './dataset/cropped/d2arteezy\\d2arteezy12.png',
#   './dataset/cropped/d2arteezy\\d2arteezy121.png',
#   './dataset/cropped/d2arteezy\\d2arteezy122.png',
#   './dataset/cropped/d2arteezy\\d2arteezy123.png',
#   './dataset/cropped/d2arteezy\\d2arteezy125.png',
#   './dataset/cropped/d2arteezy\\d2arteezy126.png',
#   './dataset/cropped/d2arteezy\\d2arteezy128.png',
#   './dataset/cropped/d2arteezy\\d2arteezy129.png',
#   './dataset/cropped/d2arteezy\\d2arteezy13.png',
#   './dataset/cropped/d2arteezy\\d2arteezy14.png',
#   './dataset/cropped/d2arteezy\\d2arteezy15.png',
#   './dataset/cropped/d2arteezy\\d2arteezy17.png',
#   './dataset/cropped/d2arteezy\\d2arteezy18.png',
#   './dataset/cropped/d2arteezy\\d2arteezy19.png',
#   './dataset/cropped/d2arteezy\\d2arteezy20.png',
#   './dataset/cropped/d2arteezy\\d2arteezy23.png',
#   './dataset/cropped/d2arteezy\\d2arteezy26.png',
#   './dataset/cropped/d2arteezy\\d2arteezy27.png',
#   './dataset/cropped/d2arteezy\\d2arteezy28.png',
#   './dataset/cropped/d2arteezy\\d2arteezy3.png',
#   './dataset/cropped/d2arteezy\\d2arteezy30.png',
#   './dataset/cropped/d2arteezy\\d2arteezy31.png',
#   './dataset/cropped/d2arteezy\\d2arteezy32.png',
#   './dataset/cropped/d2arteezy\\d2arteezy33.png',
#   './dataset/cropped/d2arteezy\\d2arteezy39.png',
#   './dataset/cropped/d2arteezy\\d2arteezy41.png',
#   './dataset/cropped/d2arteezy\\d2arteezy44.png',
#   './dataset/cropped/d2arteezy\\d2arteezy45.png',
#   './dataset/cropped/d2arteezy\\d2arteezy46.png',
#   './dataset/cropped/d2arteezy\\d2arteezy47.png',
#   './dataset/cropped/d2arteezy\\d2arteezy48.png',
#   './dataset/cropped/d2arteezy\\d2arteezy5.png',
#   './dataset/cropped/d2arteezy\\d2arteezy51.png',
#   './dataset/cropped/d2arteezy\\d2arteezy52.png',
#   './dataset/cropped/d2arteezy\\d2arteezy53.png',
#   './dataset/cropped/d2arteezy\\d2arteezy54.png',
#   './dataset/cropped/d2arteezy\\d2arteezy55.png',
#   './dataset/cropped/d2arteezy\\d2arteezy56.png',
#   './dataset/cropped/d2arteezy\\d2arteezy57.png',
#   './dataset/cropped/d2arteezy\\d2arteezy59.png',
#   './dataset/cropped/d2arteezy\\d2arteezy6.png',
#   './dataset/cropped/d2arteezy\\d2arteezy61.png',
#   './dataset/cropped/d2arteezy\\d2arteezy62.png',
#   './dataset/cropped/d2arteezy\\d2arteezy63.png',
#   './dataset/cropped/d2arteezy\\d2arteezy65.png',
#   './dataset/cropped/d2arteezy\\d2arteezy67.png',
#   './dataset/cropped/d2arteezy\\d2arteezy7.png',
#   './dataset/cropped/d2arteezy\\d2arteezy73.png',
#   './dataset/cropped/d2arteezy\\d2arteezy74.png',
#   './dataset/cropped/d2arteezy\\d2arteezy75.png',
#   './dataset/cropped/d2arteezy\\d2arteezy77.png',
#   './dataset/cropped/d2arteezy\\d2arteezy78.png',
#   './dataset/cropped/d2arteezy\\d2arteezy8.png',
#   './dataset/cropped/d2arteezy\\d2arteezy80.png',
#   './dataset/cropped/d2arteezy\\d2arteezy81.png',
#   './dataset/cropped/d2arteezy\\d2arteezy82.png',
#   './dataset/cropped/d2arteezy\\d2arteezy83.png',
#   './dataset/cropped/d2arteezy\\d2arteezy85.png',
#   './dataset/cropped/d2arteezy\\d2arteezy87.png',
#   './dataset/cropped/d2arteezy\\d2arteezy88.png',
#   './dataset/cropped/d2arteezy\\d2arteezy89.png',
#   './dataset/cropped/d2arteezy\\d2arteezy9.png',
#   './dataset/cropped/d2arteezy\\d2arteezy91.png',
#   './dataset/cropped/d2arteezy\\d2arteezy92.png',
#   './dataset/cropped/d2arteezy\\d2arteezy93.png',
#   './dataset/cropped/d2arteezy\\d2arteezy95.png',
#   './dataset/cropped/d2arteezy\\d2arteezy96.png',
#   './dataset/cropped/d2arteezy\\d2arteezy97.png',
#   './dataset/cropped/d2arteezy\\d2arteezy98.png',
#   './dataset/cropped/d2arteezy\\d2arteezy99.png'],
#  'd2iceiceice': ['./dataset/cropped/d2iceiceice\\d2iceiceice1.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice10.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice100.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice101.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice102.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice107.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice11.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice110.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice113.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice114.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice115.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice116.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice117.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice118.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice12.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice127.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice128.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice13.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice14.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice15.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice17.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice18.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice19.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice2.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice20.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice21.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice22.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice23.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice24.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice25.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice28.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice32.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice33.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice34.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice35.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice37.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice38.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice39.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice4.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice40.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice41.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice42.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice43.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice44.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice45.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice46.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice47.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice48.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice49.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice51.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice52.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice53.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice56.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice6.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice60.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice61.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice64.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice65.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice66.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice67.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice68.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice69.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice7.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice71.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice72.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice73.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice74.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice75.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice76.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice77.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice78.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice79.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice80.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice81.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice82.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice83.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice84.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice85.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice87.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice9.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice90.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice92.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice93.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice94.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice97.png',
#   './dataset/cropped/d2iceiceice\\d2iceiceice99.png'],
#  'd2miracle': ['./dataset/cropped/d2miracle\\d2miracle1.png',
#   './dataset/cropped/d2miracle\\d2miracle11.png',
#   './dataset/cropped/d2miracle\\d2miracle12.png',
#   './dataset/cropped/d2miracle\\d2miracle13.png',
#   './dataset/cropped/d2miracle\\d2miracle16.png',
#   './dataset/cropped/d2miracle\\d2miracle17.png',
#   './dataset/cropped/d2miracle\\d2miracle18.png',
#   './dataset/cropped/d2miracle\\d2miracle19.png',
#   './dataset/cropped/d2miracle\\d2miracle2.png',
#   './dataset/cropped/d2miracle\\d2miracle20.png',
#   './dataset/cropped/d2miracle\\d2miracle21.png',
#   './dataset/cropped/d2miracle\\d2miracle23.png',
#   './dataset/cropped/d2miracle\\d2miracle24.png',
#   './dataset/cropped/d2miracle\\d2miracle25.png',
#   './dataset/cropped/d2miracle\\d2miracle26.png',
#   './dataset/cropped/d2miracle\\d2miracle28.png',
#   './dataset/cropped/d2miracle\\d2miracle29.png',
#   './dataset/cropped/d2miracle\\d2miracle3.png',
#   './dataset/cropped/d2miracle\\d2miracle30.png',
#   './dataset/cropped/d2miracle\\d2miracle32.png',
#   './dataset/cropped/d2miracle\\d2miracle34.png',
#   './dataset/cropped/d2miracle\\d2miracle35.png',
#   './dataset/cropped/d2miracle\\d2miracle36.png',
#   './dataset/cropped/d2miracle\\d2miracle37.png',
#   './dataset/cropped/d2miracle\\d2miracle38.png',
#   './dataset/cropped/d2miracle\\d2miracle39.png',
#   './dataset/cropped/d2miracle\\d2miracle40.png',
#   './dataset/cropped/d2miracle\\d2miracle43.png',
#   './dataset/cropped/d2miracle\\d2miracle44.png',
#   './dataset/cropped/d2miracle\\d2miracle48.png',
#   './dataset/cropped/d2miracle\\d2miracle5.png',
#   './dataset/cropped/d2miracle\\d2miracle51.png',
#   './dataset/cropped/d2miracle\\d2miracle52.png',
#   './dataset/cropped/d2miracle\\d2miracle55.png',
#   './dataset/cropped/d2miracle\\d2miracle56.png',
#   './dataset/cropped/d2miracle\\d2miracle57.png',
#   './dataset/cropped/d2miracle\\d2miracle58.png',
#   './dataset/cropped/d2miracle\\d2miracle59.png',
#   './dataset/cropped/d2miracle\\d2miracle6.png',
#   './dataset/cropped/d2miracle\\d2miracle65.png',
#   './dataset/cropped/d2miracle\\d2miracle67.png',
#   './dataset/cropped/d2miracle\\d2miracle68.PNG',
#   './dataset/cropped/d2miracle\\d2miracle7.png',
#   './dataset/cropped/d2miracle\\d2miracle70.PNG',
#   './dataset/cropped/d2miracle\\d2miracle71.PNG',
#   './dataset/cropped/d2miracle\\d2miracle72.PNG',
#   './dataset/cropped/d2miracle\\d2miracle73.PNG',
#   './dataset/cropped/d2miracle\\d2miracle74.PNG',
#   './dataset/cropped/d2miracle\\d2miracle75.PNG',
#   './dataset/cropped/d2miracle\\d2miracle9.png'],
#  'd2puppey': ['./dataset/cropped/d2puppey\\d2puppey10.png',
#   './dataset/cropped/d2puppey\\d2puppey100.png',
#   './dataset/cropped/d2puppey\\d2puppey101.png',
#   './dataset/cropped/d2puppey\\d2puppey102.png',
#   './dataset/cropped/d2puppey\\d2puppey103.png',
#   './dataset/cropped/d2puppey\\d2puppey104.png',
#   './dataset/cropped/d2puppey\\d2puppey105.png',
#   './dataset/cropped/d2puppey\\d2puppey106.png',
#   './dataset/cropped/d2puppey\\d2puppey11.png',
#   './dataset/cropped/d2puppey\\d2puppey111.png',
#   './dataset/cropped/d2puppey\\d2puppey113.png',
#   './dataset/cropped/d2puppey\\d2puppey114.png',
#   './dataset/cropped/d2puppey\\d2puppey115.png',
#   './dataset/cropped/d2puppey\\d2puppey116.png',
#   './dataset/cropped/d2puppey\\d2puppey12.png',
#   './dataset/cropped/d2puppey\\d2puppey126.png',
#   './dataset/cropped/d2puppey\\d2puppey127.png',
#   './dataset/cropped/d2puppey\\d2puppey128.png',
#   './dataset/cropped/d2puppey\\d2puppey130.png',
#   './dataset/cropped/d2puppey\\d2puppey131.png',
#   './dataset/cropped/d2puppey\\d2puppey135.png',
#   './dataset/cropped/d2puppey\\d2puppey139.png',
#   './dataset/cropped/d2puppey\\d2puppey143.png',
#   './dataset/cropped/d2puppey\\d2puppey144.png',
#   './dataset/cropped/d2puppey\\d2puppey145.png',
#   './dataset/cropped/d2puppey\\d2puppey148.png',
#   './dataset/cropped/d2puppey\\d2puppey150.png',
#   './dataset/cropped/d2puppey\\d2puppey151.png',
#   './dataset/cropped/d2puppey\\d2puppey17.png',
#   './dataset/cropped/d2puppey\\d2puppey18.png',
#   './dataset/cropped/d2puppey\\d2puppey19.png',
#   './dataset/cropped/d2puppey\\d2puppey2.png',
#   './dataset/cropped/d2puppey\\d2puppey20.png',
#   './dataset/cropped/d2puppey\\d2puppey21.png',
#   './dataset/cropped/d2puppey\\d2puppey25.png',
#   './dataset/cropped/d2puppey\\d2puppey26.png',
#   './dataset/cropped/d2puppey\\d2puppey27.png',
#   './dataset/cropped/d2puppey\\d2puppey28.png',
#   './dataset/cropped/d2puppey\\d2puppey29.png',
#   './dataset/cropped/d2puppey\\d2puppey3.png',
#   './dataset/cropped/d2puppey\\d2puppey31.png',
#   './dataset/cropped/d2puppey\\d2puppey33.png',
#   './dataset/cropped/d2puppey\\d2puppey34.png',
#   './dataset/cropped/d2puppey\\d2puppey36.png',
#   './dataset/cropped/d2puppey\\d2puppey39.png',
#   './dataset/cropped/d2puppey\\d2puppey4.png',
#   './dataset/cropped/d2puppey\\d2puppey40.png',
#   './dataset/cropped/d2puppey\\d2puppey41.png',
#   './dataset/cropped/d2puppey\\d2puppey42.png',
#   './dataset/cropped/d2puppey\\d2puppey43.png',
#   './dataset/cropped/d2puppey\\d2puppey44.png',
#   './dataset/cropped/d2puppey\\d2puppey45.png',
#   './dataset/cropped/d2puppey\\d2puppey46.png',
#   './dataset/cropped/d2puppey\\d2puppey47.png',
#   './dataset/cropped/d2puppey\\d2puppey48.png',
#   './dataset/cropped/d2puppey\\d2puppey49.png',
#   './dataset/cropped/d2puppey\\d2puppey5.png',
#   './dataset/cropped/d2puppey\\d2puppey50.png',
#   './dataset/cropped/d2puppey\\d2puppey51.png',
#   './dataset/cropped/d2puppey\\d2puppey54.png',
#   './dataset/cropped/d2puppey\\d2puppey56.png',
#   './dataset/cropped/d2puppey\\d2puppey58.png',
#   './dataset/cropped/d2puppey\\d2puppey6.png',
#   './dataset/cropped/d2puppey\\d2puppey60.png',
#   './dataset/cropped/d2puppey\\d2puppey62.png',
#   './dataset/cropped/d2puppey\\d2puppey64.png',
#   './dataset/cropped/d2puppey\\d2puppey65.png',
#   './dataset/cropped/d2puppey\\d2puppey67.png',
#   './dataset/cropped/d2puppey\\d2puppey69.png',
#   './dataset/cropped/d2puppey\\d2puppey7.png',
#   './dataset/cropped/d2puppey\\d2puppey70.png',
#   './dataset/cropped/d2puppey\\d2puppey71.png',
#   './dataset/cropped/d2puppey\\d2puppey73.png',
#   './dataset/cropped/d2puppey\\d2puppey74.png',
#   './dataset/cropped/d2puppey\\d2puppey76.png',
#   './dataset/cropped/d2puppey\\d2puppey77.png',
#   './dataset/cropped/d2puppey\\d2puppey8.png',
#   './dataset/cropped/d2puppey\\d2puppey85.png',
#   './dataset/cropped/d2puppey\\d2puppey86.png',
#   './dataset/cropped/d2puppey\\d2puppey87.png',
#   './dataset/cropped/d2puppey\\d2puppey88.png',
#   './dataset/cropped/d2puppey\\d2puppey89.png',
#   './dataset/cropped/d2puppey\\d2puppey9.png',
#   './dataset/cropped/d2puppey\\d2puppey90.png',
#   './dataset/cropped/d2puppey\\d2puppey91.png',
#   './dataset/cropped/d2puppey\\d2puppey92.png',
#   './dataset/cropped/d2puppey\\d2puppey93.png',
#   './dataset/cropped/d2puppey\\d2puppey96.png',
#   './dataset/cropped/d2puppey\\d2puppey97.png',
#   './dataset/cropped/d2puppey\\d2puppey98.png',
#   './dataset/cropped/d2puppey\\d2puppey99.png'],
#  'd2zai': ['./dataset/cropped/d2zai\\d2zai10.png',
#   './dataset/cropped/d2zai\\d2zai11.png',
#   './dataset/cropped/d2zai\\d2zai12.png',
#   './dataset/cropped/d2zai\\d2zai13.png',
#   './dataset/cropped/d2zai\\d2zai14.png',
#   './dataset/cropped/d2zai\\d2zai15.png',
#   './dataset/cropped/d2zai\\d2zai17.png',
#   './dataset/cropped/d2zai\\d2zai19.png',
#   './dataset/cropped/d2zai\\d2zai20.png',
#   './dataset/cropped/d2zai\\d2zai21.png',
#   './dataset/cropped/d2zai\\d2zai22.png',
#   './dataset/cropped/d2zai\\d2zai23.png',
#   './dataset/cropped/d2zai\\d2zai24.png',
#   './dataset/cropped/d2zai\\d2zai26.png',
#   './dataset/cropped/d2zai\\d2zai27.png',
#   './dataset/cropped/d2zai\\d2zai29.png',
#   './dataset/cropped/d2zai\\d2zai32.png',
#   './dataset/cropped/d2zai\\d2zai33.png',
#   './dataset/cropped/d2zai\\d2zai34.png',
#   './dataset/cropped/d2zai\\d2zai35.png',
#   './dataset/cropped/d2zai\\d2zai36.png',
#   './dataset/cropped/d2zai\\d2zai37.png',
#   './dataset/cropped/d2zai\\d2zai4.png',
#   './dataset/cropped/d2zai\\d2zai40.png',
#   './dataset/cropped/d2zai\\d2zai42.png',
#   './dataset/cropped/d2zai\\d2zai43.png',
#   './dataset/cropped/d2zai\\d2zai44.png',
#   './dataset/cropped/d2zai\\d2zai45.png',
#   './dataset/cropped/d2zai\\d2zai46.png',
#   './dataset/cropped/d2zai\\d2zai47.png',
#   './dataset/cropped/d2zai\\d2zai48.png',
#   './dataset/cropped/d2zai\\d2zai49.png',
#   './dataset/cropped/d2zai\\d2zai5.png',
#   './dataset/cropped/d2zai\\d2zai50.png',
#   './dataset/cropped/d2zai\\d2zai51.png',
#   './dataset/cropped/d2zai\\d2zai52.png',
#   './dataset/cropped/d2zai\\d2zai53.png',
#   './dataset/cropped/d2zai\\d2zai54.png',
#   './dataset/cropped/d2zai\\d2zai55.png',
#   './dataset/cropped/d2zai\\d2zai56.png',
#   './dataset/cropped/d2zai\\d2zai58.png',
#   './dataset/cropped/d2zai\\d2zai6.png',
#   './dataset/cropped/d2zai\\d2zai62.png',
#   './dataset/cropped/d2zai\\d2zai63.png',
#   './dataset/cropped/d2zai\\d2zai64.png',
#   './dataset/cropped/d2zai\\d2zai66.png',
#   './dataset/cropped/d2zai\\d2zai67.png',
#   './dataset/cropped/d2zai\\d2zai68.png',
#   './dataset/cropped/d2zai\\d2zai69.png',
#   './dataset/cropped/d2zai\\d2zai7.png',
#   './dataset/cropped/d2zai\\d2zai70.png',
#   './dataset/cropped/d2zai\\d2zai72.png',
#   './dataset/cropped/d2zai\\d2zai73.png',
#   './dataset/cropped/d2zai\\d2zai74.png',
#   './dataset/cropped/d2zai\\d2zai75.png',
#   './dataset/cropped/d2zai\\d2zai76.png',
#   './dataset/cropped/d2zai\\d2zai78.png',
#   './dataset/cropped/d2zai\\d2zai79.png',
#   './dataset/cropped/d2zai\\d2zai8.png',
#   './dataset/cropped/d2zai\\d2zai81.png',
#   './dataset/cropped/d2zai\\d2zai82.png',
#   './dataset/cropped/d2zai\\d2zai83.png',
#   './dataset/cropped/d2zai\\d2zai84.png',
#   './dataset/cropped/d2zai\\d2zai87.png',
#   './dataset/cropped/d2zai\\d2zai88.png',
#   './dataset/cropped/d2zai\\d2zai89.png',
#   './dataset/cropped/d2zai\\d2zai9.png',
#   './dataset/cropped/d2zai\\d2zai90.png',
#   './dataset/cropped/d2zai\\d2zai93.png']}

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
class_dict = {}
count = 0
for player_name in player_file_name.keys():
    class_dict[player_name] = count
    count = count + 1
class_dict
# Out:
# {'d2arteezy': 0, 'd2iceiceice': 1, 'd2miracle': 2, 'd2puppey': 3, 'd2zai': 4}

# %%
x=[]
y=[]
for player_name, training_files in player_file_name.items():
    for training_image in training_files:
        img =cv2.imread(training_image)
        if img is None:
            continue
        scaled_raw_img=cv2.resize(img,(32,32))
        img_har =w2d(img,'db1',5)
        scaled_img_har=cv2.resize(img_har,(32,32))
        combined_img=np.vstack((scaled_raw_img.reshape(32*32*3,1),scaled_img_har.reshape(32*32,1)))
        x.append(combined_img)
        y.append(class_dict[player_name])

# %%
len(y)
# Out:
# 382

# %%
x=np.array(x).reshape(len(x),4096).astype(float)
x.shape
# Out:
# (382, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, random_state = 4)

pipe=Pipeline([('scaler',StandardScaler()),('svc',SVC(kernel='rbf',C=10))])
pipe.fit(X_train,y_train)
pipe.score(X_test,y_test)
# Out:
# 0.7604166666666666

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.78      0.81      0.79        26
#            1       0.83      0.91      0.87        22
#            2       0.86      0.67      0.75         9
#            3       0.57      0.80      0.67        20
#            4       1.00      0.53      0.69        19
#
#     accuracy                           0.76        96
#    macro avg       0.81      0.74      0.75        96
# weighted avg       0.80      0.76      0.76        96

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.755717
# 1        random_forest    0.583908
# 2  logistic_regression    0.755414
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                 {'logisticregression__C': 10}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=10, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8229166666666666

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5729166666666666

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.7604166666666666

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[21,  1,  1,  1,  2],
#        [ 1, 21,  0,  0,  0],
#        [ 0,  0,  9,  0,  0],
#        [ 1,  0,  1, 18,  0],
#        [ 3,  1,  0,  5, 10]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
import joblib
joblib.dump(best_clf,'saved_model.pkl')
# Out:
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
